# %%
from src import ImageDeepHash

# %%
m = ImageDeepHash.ImageDeepHash()
m.hash("ILSVRC2012_val_00005002.jpeg")
print(m.digest())
print(m.hexdigest())
m.plot()
# Out:
# b'J\xc2Zi?d.\x8d\x84av\xa6+=\x83F'
# 0x4ac25a693f642e8d846176a62b3d8346

# %%
m.reset()
m.hash("ILSVRC2012_val_00005002_noise.jpeg")
print(m.digest())
print(m.hexdigest())
m.plot()
# Out:
# b'J\xc2Zi?d.\x8d\x84av\xa6+=\x83F'
# 0x4ac25a693f642e8d846176a62b3d8346

# %%
m.reset()
m.hash("ILSVRC2012_val_00005004.jpeg")
print(m.digest())
print(m.hexdigest())
m.plot()
# Out:
# b'\n\xe2^k?t|\x8d\x94av\xc6+=\x83F'
# 0xae25e6b3f747c8d946176c62b3d8346
