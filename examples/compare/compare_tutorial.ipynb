# %%
from src import ImageDeepCompare

# %%
m = ImageDeepCompare.ImageDeepCompare()
print("Distance:", m.compare("ILSVRC2012_val_00005002.jpeg", "ILSVRC2012_val_00005002_noise.jpeg", "euclidean"))
m.plot()
# Out:
# Distance: 0.0029359916

# %%
print("Distance:", m.compare("ILSVRC2012_val_00005002.jpeg", "ILSVRC2012_val_00005004.jpeg", "euclidean"))
m.plot()
# Out:
# Distance: 0.026431153

# %%
print("Distance:", m.compare("ILSVRC2012_val_00005002.jpeg", "000014b1f770f640.jpg", "euclidean"))
m.plot()
# Out:
# Distance: 0.16201928
